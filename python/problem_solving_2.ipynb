# %% [markdown]
# ### Problem 1: Print Numbers 1–n using for loop
#
# ### use of break and continue (Skip Number 5 )

# %% [markdown]
# ### Problem 2: Print Even Numbers up to n

# %% [markdown]
# ### problem 3: Sum Until Zero Input

# %% [markdown]
# ### Problem 4: Create and Access a List

# %% [markdown]
# ### Problem 5: Slicing a List

# %% [markdown]
# ### Problem 6: Sort a List of Numbers

# %% [markdown]
# ### Problem 7: Zip Two Lists

# %% [markdown]
# ### Problem 8: List Comprehension (Squares)

# %% [markdown]
# ### Problem 9:Sort and Remove Duplicates

# %% [markdown]
# ### Problem 10: Create and Access Tuple

# %% [markdown]
# ### Problem 11: Count and Index

# %% [markdown]
# ### Problem 12: Create and Access Set

# %% [markdown]
# ### Problem 13: Add and Remove Elements

# %% [markdown]
# ### Problem 14: Set Operations

# %% [markdown]
# ### Problem 15: Subset and Superset

# %% [markdown]
# ### Problem 16: Convert Between Set and List

# %% [markdown]
# ### Problem 17: Create Dictionary of Squares

# %% [markdown]
# ### Problem 18: Access Elements

# %% [markdown]
# ### Problem 19: Add and Remove Pairs

# %% [markdown]
# ### Problem 20: Iterate Over Dictionary

# %% [markdown]
# ### Problem 21: Merge Two Dictionaries

# %% [markdown]
# ### Problem 22: Nested Dictionary (Student Record)

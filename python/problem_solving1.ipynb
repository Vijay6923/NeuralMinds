# %% [markdown]
# ### Problem 1: Print User Input
# Task: Take input from the user and print it.

# %% [markdown]
# ### Problem 2: Check Positive, Negative, or Zero

# %% [markdown]
# ### Problem 3: Largest of Three Numbers

# %% [markdown]
# ### Problem 4: Factorial of a Number

# %% [markdown]
# ### Problem 5: Swap Two Variables

# %% [markdown]
# ### Problem 6: Celsius to Fahrenheit

# %% [markdown]
# ### Problem 7: Concatenate Two Strings

# %% [markdown]
# ### Problem 8: Arithmetic Operations

# %% [markdown]
# ### Problem 9: Even or Odd

# %% [markdown]
# ### Problem 10: Sum of First n Natural Numbers

# %% [markdown]
# ### Problem 11: Reverse a String

# %% [markdown]
# ### Problem 12:  Check given string is Palindrome or not

# %% [markdown]
# ### Problem 14: Sort a List of Numbers

# %% [markdown]
# ### Problem 15: Print Numbers 1–10 using for loop

# %% [markdown]
# ### use of break and continue (Problem 17: Skip Number 5 )

# %% [markdown]
# ### Problem 18: Print Even Numbers up to n

# %% [markdown]
# ### problem--> Sum Until Zero Input

# %% [markdown]
# “That’s it for Part 1! We’ve solved 21 problems, covering inputs, operators, loops, and conditionals.
#
# Remember: Understand why each step is used, not just the code. Once you know the logic, new problems become easy.
#
# In the next video, we’ll tackle lists, tuples, sets, dictionaries, and more challenging exercises.
#
# If you liked this video, don’t forget to like, share, and subscribe to Neural Minds. See you in the next one!”

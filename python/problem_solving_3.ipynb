# %% [markdown]
# ### Problem 1: Create Dictionary of Squares

# %% [markdown]
# ### Problem 2: Access Elements

# %% [markdown]
# ### Problem 3: Add and Remove Pairs

# %% [markdown]
# ### Problem 4: Iterate Over Dictionary

# %% [markdown]
# ### Problem 5: Merge Two Dictionaries

# %% [markdown]
# ### Problem 6: Swap Keys and Values

# %% [markdown]
# ### Problem 7: Count Frequency of Each Element (Word Count)

# %% [markdown]
# ### problem 8: Create Dictionary from Two Lists

# %% [markdown]
# ### problem 9 : Create Dictionary from Two Lists And write a function to print each student’s average marks.

# %% [markdown]
# ### problem 10 : Function to Compute Mean

# %% [markdown]
# ### problem 11: Standard Deviation Function

# %% [markdown]
# ### problem 12 : Normalize List using Min-Max Scaling

# %% [markdown]
# ### problem 13 : Write a recursive function to calculate factorial.

# %% [markdown]
# ### problem 14 : Write a function that takes two numbers and returns a tuple (sum, difference, product).

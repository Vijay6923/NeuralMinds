# %% [markdown]
# ### 1. What is NumPy
# ### 2. Why NumPy is faster
# ### 3. Creating arrays
# ### 4. Random numbers
# ### 5. Array attributes
# ### 6. Indexing + slicing
# ### 7. Arithmetic operations
# ### 8. Matrix multiplication / dot
# ### 9. Helper functions

# %% [markdown]
# ### Numpy
#
# ### NumPy is a popular Python library used for working with numbers. It lets you create large arrays (lists of numbers) and do math on them very quickly. It’s faster than normal Python lists because the numbers are stored in one continuous place in memory, which makes calculations efficient. Most data science and machine learning tools use NumPy at the core for handling numerical data.
